# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import re

# Define the folders
folders = ['Dissertations', 'Master', 'Undergraduate']

# Initialize a counter for rows with 'IPB (Bogor Agricultural University)' in the 'title' column
ipb_count_total = 0

# Define the regex pattern for the 'title' column
title_pattern = r'^dc\.title'

# Function to extract columns based on regex pattern and select the first non-null value
def extract_columns(df, pattern):
    matching_columns = [col for col in df.columns if re.match(pattern, col)]
    if matching_columns:
        # Select the first non-null value across the matching columns
        return df[matching_columns].bfill(axis=1).iloc[:, 0]
    else:
        return pd.Series([None] * len(df))

# Loop through each folder
for folder in folders:
    # Loop through each CSV file in the folder
    for filename in os.listdir(f"/content/drive/MyDrive/Colab Notebooks/dataset_magang/{folder}/csv/"):
        if filename.endswith('.csv'):
            # Construct the file path
            file_path = os.path.join(f"/content/drive/MyDrive/Colab Notebooks/dataset_magang/{folder}/csv/", filename)

            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path)

            # Extract the 'title' column using the regex pattern
            title_column = extract_columns(df, title_pattern)

            # Filter the DataFrame for rows where 'title' is 'IPB (Bogor Agricultural University)'
            filtered_df = df[title_column == 'IPB (Bogor Agricultural University)']

            # Print the filtered DataFrame
            if not filtered_df.empty:
                print(f"Filtered rows from file: {filename}")
                print(filtered_df)

            # Count rows where 'title' contains 'IPB (Bogor Agricultural University)' within this file
            ipb_count = filtered_df.shape[0]
            ipb_count_total += ipb_count

# Print the total count of 'IPB (Bogor Agricultural University)' rows across all files
print(f"Total number of rows with 'IPB (Bogor Agricultural University)' in the 'title' column: {ipb_count_total}")
# Out:
# Filtered rows from file: DT - Economic and Management.csv
#                                        id    collection dc.contributor.author  \
# 196  68ba90bc-a8c3-4129-8b27-a4989ffd1942  123456789/85                   NaN
# 345  bfba38ff-b80b-44f9-bb36-53331e5084c6  123456789/85                   NaN
# 382  d577713f-2f63-41b8-9e97-73c087db2041  123456789/85                   NaN
# 414  e66ec644-5eb8-4cdf-8a54-7cbe01541007  123456789/85                   NaN
#
#        dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 196      Nasution, H. Muslimin               NaN                     NaN
# 345  Simanjuntak, Sahat Barita               NaN                     NaN
# 382                 Tatuh, Jen               NaN                     NaN
# 414               Saleh, Deddy               NaN                     NaN
#
#                              dc.description.abstract[]  \
# 196  Tujuan penelitian ialah untuk mengidentifikasi...
# 345  The objectives of the study is to analyse comp...
# 382  Kontrak Tumpang Sari dan Perhutanan Sosial ada...
# 414  With the background of Indonesia being the mai...
#
#     dc.description.abstract[en] dc.description.abstract[id]  \
# 196                         NaN                         NaN
# 345                         NaN                         NaN
# 382                         NaN                         NaN
# 414                         NaN                         NaN
#
#                          dc.description.provenance[en]  ...  \
# 196  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...
# 345  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...
# 382  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...
# 414  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...
#
#      dc.title.alternative[en]             dc.title.alternative[id]  \
# 196                       NaN  IPB (Bogor Agricultural University)
# 345                       NaN  IPB (Bogor Agricultural University)
# 382                       NaN  IPB (Bogor Agricultural University)
# 414                       NaN  IPB (Bogor Agricultural University)
#
#                                             dc.title[] dc.title[en]  \
# 196                                                NaN          NaN
# 345  Analysis of competitiveness and impact of the ...          NaN
# 382                                                NaN          NaN
# 414                                                NaN          NaN
#
#     dc.title[en_EN]                                       dc.title[id]  \
# 196             NaN  Keragaan koperasi unit desa sebagai organisasi...
# 345             NaN  Analisis daya saing dan dampak kebijaksanaan p...
# 382             NaN  Analisis kontrak dalam kegiatan peremajaan hut...
# 414             NaN  Optimalisasi produksi dan pemasaran karet alam...
#
#     dc.type dc.type[] dc.type[en] dc.type[id]
# 196     NaN       NaN         NaN         NaN
# 345     NaN       NaN         NaN         NaN
# 382     NaN       NaN         NaN         NaN
# 414     NaN       NaN         NaN         NaN
#
# [4 rows x 42 columns]
# Filtered rows from file: DT - Human Ecology.csv
#                                        id    collection dc.contributor.author  \
# 541  fb0a9445-d97c-4a41-9d9f-ebebeb0abd68  123456789/88                   NaN
#
#     dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 541          Fadjar, Undang               NaN                     NaN
#
#     dc.description.abstract[] dc.description.abstract[en]  \
# 541                       NaN                         NaN
#
#                            dc.description.abstract[id]  \
# 541  This research analyses about how and how far t...
#
#     dc.description.abstract[ind]  ... dc.title.alternative[]  \
# 541                          NaN  ...                    NaN
#
#     dc.title.alternative[en]             dc.title.alternative[id] dc.title[]  \
# 541                      NaN  IPB (Bogor Agricultural University)        NaN
#
#     dc.title[en]                                       dc.title[id]  \
# 541          NaN  Agrarian structure transformation and social d...
#
#     dc.title[in_ID] dc.type dc.type[] dc.type[id]
# 541             NaN     NaN       NaN         NaN
#
# [1 rows x 44 columns]
# Filtered rows from file: DT - Veterinary Science.csv
#                                        id    collection  \
# 0    0270e454-0a37-4716-97a5-9dde105226e7  123456789/92
# 1    02813fa9-ac11-4491-a6ba-f50f2dbc4ad1  123456789/92
# 2    03b5c1b7-3641-4ae0-9b03-46ab3895ac19  123456789/92
# 5    05a707a3-091b-45a1-8d63-194c321dad63  123456789/92
# 7    0c16ab0f-53ad-41ce-9e0c-b6147bdbfddd  123456789/92
# ..                                    ...           ...
# 276  f45a49b5-6c22-450b-b03b-c971bf5e1483  123456789/92
# 277  f726c55e-2572-41ad-9d52-fee4dbe8708a  123456789/92
# 283  fb582807-8b72-4f3f-9b30-24b3c7a13498  123456789/92
# 284  fea1c8bd-a3f9-4100-96fc-b50091a329fb  123456789/92
# 285  fec103e6-0e4b-4fd2-ace2-941c7c56e56c  123456789/92
#
#      dc.contributor.author     dc.contributor.author[] dc.date.updated[]  \
# 0             Aswani, Tuti                         NaN               NaN
# 1                      NaN                    Eddy, La               NaN
# 2                      NaN         Kusumaningsih, Anni               NaN
# 5        Widiyani, Platika                         NaN               NaN
# 7           Dewi, Cut Dara                         NaN               NaN
# ..                     ...                         ...               ...
# 276                    NaN           Darmakusuma, Dodi               NaN
# 277  Daulay, Mazdani Ulfah                         NaN               NaN
# 283                    NaN       Solihati, Nurcholidah               NaN
# 284                    NaN  Angi, Andrijanto Hauferson               NaN
# 285                    NaN         Wiradimadja, Rahmat               NaN
#
#     dc.description.abstract  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 5                       NaN
# 7                       NaN
# ..                      ...
# 276                     NaN
# 277                     NaN
# 283                     NaN
# 284                     NaN
# 285                     NaN
#
#                              dc.description.abstract[]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 5                                                  NaN
# 7                                                  NaN
# ..                                                 ...
# 276  Kulit merupakan organ terbesar yangbersetntuha...
# 277                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                            dc.description.abstract[en]  \
# 0                                                  NaN
# 1    Mutiara yang berkualitas sangat bergantung pad...
# 2    Salmonellosis yang disebabkan oleh Salmonella ...
# 5                                                  NaN
# 7                                                  NaN
# ..                                                 ...
# 276  Skin is the largest organ that direct contact ...
# 277                                                NaN
# 283  The Indonesia population growth rate during th...
# 284  Trichinellosis adalah penyakit akibat cacing n...
# 285  Penggunaan tepung daun katuk dalam ransum ayam...
#
#                            dc.description.abstract[id]  \
# 0    Parasetamol merupakan salah satu di antara oba...
# 1                                                  NaN
# 2                                                  NaN
# 5    Indonesia sebagai eksportir dan produsen saran...
# 7    Ikan patin siam memiliki nilai ekonomis yang s...
# ..                                                 ...
# 276                                                NaN
# 277  Tuberculosis (TB) is one of the most wide-spre...
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                          dc.description.provenance[en]  ...  dc.subject[en]  \
# 0    Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# 1    Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# 2    Submitted by Rika Sulastri (rikawebo@ipb.ac.id...  ...             NaN
# 5    Submitted by WIDIYANI (drh_platika@yahoo.co.id...  ...             NaN
# 7    Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# ..                                                 ...  ...             ...
# 276  Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# 277  Submitted by Fika Lestari (fika@ipb.ac.id) on ...  ...             NaN
# 283  Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# 284  Submitted by Didin Mulyadi (didinmu@ipb.ac.id)...  ...             NaN
# 285  Submitted by Rika Sulastri (rikawebo@ipb.ac.id...  ...             NaN
#
#     dc.title.alternative dc.title.alternative[]  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 5                    NaN                    NaN
# 7                    NaN                    NaN
# ..                   ...                    ...
# 276                  NaN                    NaN
# 277                  NaN                    NaN
# 283                  NaN                    NaN
# 284                  NaN                    NaN
# 285                  NaN                    NaN
#
#                 dc.title.alternative[en]             dc.title.alternative[id]  \
# 0                                    NaN  IPB (Bogor Agricultural University)
# 1    IPB (Bogor Agricultural University)                                  NaN
# 2    IPB (Bogor Agricultural University)                                  NaN
# 5                                    NaN  IPB (Bogor Agricultural University)
# 7                                    NaN  IPB (Bogor Agricultural University)
# ..                                   ...                                  ...
# 276  IPB (Bogor Agricultural University)                                  NaN
# 277                                  NaN  IPB (Bogor Agricultural University)
# 283  IPB (Bogor Agricultural University)                                  NaN
# 284  IPB (Bogor Agricultural University)                                  NaN
# 285  IPB (Bogor Agricultural University)                                  NaN
#
#     dc.title[]                                       dc.title[en]  \
# 0          NaN                                                NaN
# 1          NaN  Proses pembentukan kantung mutiara pada tiram ...
# 2          NaN  Profil dan gen resistensi antimikroba Salmonel...
# 5          NaN                                                NaN
# 7          NaN                                                NaN
# ..         ...                                                ...
# 276        NaN  Development of candidate of antiphotoaging act...
# 277        NaN                                                NaN
# 283        NaN  Antifertilitas Ekstrak Pegagan (Centella asiat...
# 284        NaN  Prevalensi Trichinellosis pada Babi di Rumah P...
# 285        NaN  Dinamika status kolesterol pada puyuh jepang (...
#
#                                           dc.title[id] dc.type   dc.type[id]
# 0    Pengaruh Ekstrak Pegagan (Centella Asiatica L....     NaN  Dissertation
# 1                                                  NaN     NaN           NaN
# 2                                                  NaN     NaN           NaN
# 5    Kadar Nitrit pada Sarang Burung Walet dan Anal...     NaN  Dissertation
# 7    Suplementasi tepung kunyit (Curcuma longa), ti...     NaN  Dissertation
# ..                                                 ...     ...           ...
# 276                                                NaN     NaN           NaN
# 277  Kajian Prevalensi dan Faktor Risiko Penyakit T...     NaN  Dissertation
# 283                                                NaN     NaN           NaN
# 284                                                NaN     NaN           NaN
# 285                                                NaN     NaN           NaN
#
# [187 rows x 39 columns]
# Filtered rows from file: DT - Agriculture Technology.csv
#                                        id    collection dc.contributor.author  \
# 441  b15419f5-bcd1-4cee-baf8-79631e024189  123456789/83                   NaN
# 520  d1be4f43-37eb-4e27-acd7-649ecb9affc0  123456789/83                   NaN
# 564  e697f923-29a8-417a-99bd-55f4b10a33f4  123456789/83                   NaN
# 567  e6fe16e5-43f5-44a7-a00c-1dbaf987bbfb  123456789/83                   NaN
# 631  fb83b296-dfa0-4647-bbd0-ae317e6c54b1  123456789/83                   NaN
#
#      dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 441          Septiana, Siska               NaN                     NaN
# 520           Ananto, E. Eko               NaN                     NaN
# 564  Jenie, Betty Sri Laksmi               NaN                     NaN
# 567      Didu, Muhammad Said               NaN                     NaN
# 631                  Darmadi               NaN                     NaN
#
#                              dc.description.abstract[]  \
# 441                                                NaN
# 520  Tujuan penelitian ini adalah dana membangun mo...
# 564  Teknik imobilitas merupakan salah satu teknik ...
# 567  Produk pertanian dan agroindustri meningkat pe...
# 631  Tujuan penelitian ini adalah untuk mengembangk...
#
#     dc.description.abstract[en]  \
# 441                         NaN
# 520                         NaN
# 564                         NaN
# 567                         NaN
# 631                         NaN
#
#                            dc.description.abstract[id]  \
# 441  Minyak atsiri kayu putih (MKP) asal Pulau Buru...
# 520                                                NaN
# 564                                                NaN
# 567                                                NaN
# 631                                                NaN
#
#     dc.description.abstract[ind]  ... dc.title.alternative[]  \
# 441                          NaN  ...                    NaN
# 520                          NaN  ...                    NaN
# 564                          NaN  ...                    NaN
# 567                          NaN  ...                    NaN
# 631                          NaN  ...                    NaN
#
#     dc.title.alternative[en]             dc.title.alternative[id] dc.title[]  \
# 441                      NaN  IPB (Bogor Agricultural University)        NaN
# 520                      NaN  IPB (Bogor Agricultural University)        NaN
# 564                      NaN  IPB (Bogor Agricultural University)        NaN
# 567                      NaN  IPB (Bogor Agricultural University)        NaN
# 631                      NaN  IPB (Bogor Agricultural University)        NaN
#
#                                           dc.title[en]  \
# 441                                                NaN
# 520                                                NaN
# 564                                                NaN
# 567  Design of decision support system on oil-palm ...
# 631                                                NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 441  Metabolomik Berbasis GC-MS Minyak Atsiri Kayu ...     NaN       NaN
# 520  Simulasi model untuk mengevaluasi penerapan te...     NaN       NaN
# 564  Kajian teknik imobilisasi kapang penghasil sel...     NaN       NaN
# 567  Rancang bangun sistem penunjang keputusan peng...     NaN       NaN
# 631  Analisis hidrograf satuan berdasarkan paramete...     NaN       NaN
#
#     dc.type[en]   dc.type[id]
# 441         NaN  Dissertation
# 520         NaN           NaN
# 564         NaN           NaN
# 567         NaN           NaN
# 631         NaN           NaN
#
# [5 rows x 41 columns]
# Filtered rows from file: DT - Forestry.csv
#                                        id    collection dc.contributor.author  \
# 105  4eef0b68-5b15-4c95-936c-d9c2f7743fc5  123456789/87                   NaN
# 270  b806f9fb-0001-4a59-b86b-61afa9262ba3  123456789/87                   NaN
# 306  db9cb77b-5272-4a18-a3ce-8b0344ccba01  123456789/87                   NaN
#
#     dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 105       Suhendang, Endang               NaN                     NaN
# 270    Idris, Maman Mansyur               NaN                     NaN
# 306           Rachman, Osly               NaN                     NaN
#
#                              dc.description.abstract[]  \
# 105  Penelitian ini bertujuan untuk mendapatkan ben...
# 270                                                NaN
# 306  Masalah rotan Indonesia saat ini adalah belum ...
#
#     dc.description.abstract[en] dc.description.abstract[id]  \
# 105                         NaN                         NaN
# 270                         NaN                         NaN
# 306                         NaN                         NaN
#
#                          dc.description.provenance[en]  ...  dc.subject[en]  \
# 105  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...             NaN
# 270  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...             NaN
# 306  Submitted by Hana Webometrics (hana_webo@ipb.a...  ...             NaN
#
#     dc.title.alternative dc.title.alternative[]  \
# 105                  NaN                    NaN
# 270                  NaN                    NaN
# 306                  NaN                    NaN
#
#                 dc.title.alternative[id] dc.title[] dc.title[en]  \
# 105  IPB (Bogor Agricultural University)        NaN          NaN
# 270  IPB (Bogor Agricultural University)        NaN          NaN
# 306  IPB (Bogor Agricultural University)        NaN          NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 105  Hubungan antara Dimensi Tegakan Hutan Tanaman ...     NaN       NaN
# 270  Dampak Penebangan dan Penyaradan di Hutan Prod...     NaN       NaN
# 306  Peranan Sifat Anatomi, Kimia dan Fisik Terhada...     NaN       NaN
#
#     dc.type[id]
# 105         NaN
# 270         NaN
# 306         NaN
#
# [3 rows x 39 columns]
# Filtered rows from file: DT - Multidiciplinary Program.csv
#                                        id    collection dc.contributor.author  \
# 8    029f2659-4691-4d5a-a98c-942e93311d90  123456789/91                   NaN
# 13   039b1301-ad9f-4504-9ee7-139699d710e4  123456789/91                   NaN
# 17   04bf737f-d690-461a-97b2-3d76f3ac32b8  123456789/91                   NaN
# 18   04de4432-c82f-4c52-968f-339d5552b854  123456789/91                   NaN
# 19   05a1e795-f6a1-416b-8a53-f8d2e4fb730b  123456789/91                   NaN
# ..                                    ...           ...                   ...
# 751  fa53db78-80bc-421a-9baf-7345d59c3641  123456789/91                   NaN
# 753  fb697c86-9c5a-4c44-a4fd-bf6df46edbf0  123456789/91                   NaN
# 754  fc0c8342-a80c-496f-a5cd-fc5f0da2272e  123456789/91                   NaN
# 760  fdcbea17-b201-45c3-b4d1-2c51aa548537  123456789/91                   NaN
# 764  fecf6b09-9f92-4bbd-88c8-425ce944d0ca  123456789/91                   NaN
#
#     dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 8           Sigit, Nur Aeni               NaN                     NaN
# 13                 Suwardjo               NaN                     NaN
# 17           Djalal, Masrul               NaN                     NaN
# 18              Iswari, Dwi               NaN                     NaN
# 19          Widayanti, Rini               NaN                     NaN
# ..                      ...               ...                     ...
# 751      Abdulgani, Imam K.               NaN                     NaN
# 753       Suprayogi, Slamet               NaN                     NaN
# 754            Polii, Bobby               NaN                     NaN
# 760  Widyastuti, Endang Sri               NaN                     NaN
# 764          Sikong, Mas'ud               NaN                     NaN
#
#                              dc.description.abstract[]  \
# 8    Protein dalam konsentrat umumnya tahan degrada...
# 13                                                 NaN
# 17   Tujuan penelitian adalah untuk mengetahui dan ...
# 18                                                 NaN
# 19                                                 NaN
# ..                                                 ...
# 751                                                NaN
# 753  Tank model merupakan salah satu model hidrolog...
# 754  Air adalah komponen ekologis yang mutlak diper...
# 760  Permukiman kumuh memiliki pemasalahan yang dis...
# 764                                                NaN
#
#                            dc.description.abstract[en]  \
# 8                                                  NaN
# 13                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19   Tarsius merupakan salah satu satwa endemik Ind...
# ..                                                 ...
# 751                                                NaN
# 753                                                NaN
# 754                                                NaN
# 760                                                NaN
# 764                                                NaN
#
#                            dc.description.abstract[id]  \
# 8                                                  NaN
# 13                                                 NaN
# 17                                                 NaN
# 18   Jeruk merupakan salah satu komoditas pangan (k...
# 19                                                 NaN
# ..                                                 ...
# 751                                                NaN
# 753                                                NaN
# 754                                                NaN
# 760                                                NaN
# 764                                                NaN
#
#     dc.description.abstract[ind]  ... dc.title.alternative[]  \
# 8                            NaN  ...                    NaN
# 13                           NaN  ...                    NaN
# 17                           NaN  ...                    NaN
# 18                           NaN  ...                    NaN
# 19                           NaN  ...                    NaN
# ..                           ...  ...                    ...
# 751                          NaN  ...                    NaN
# 753                          NaN  ...                    NaN
# 754                          NaN  ...                    NaN
# 760                          NaN  ...                    NaN
# 764                          NaN  ...                    NaN
#
#                 dc.title.alternative[en]             dc.title.alternative[id]  \
# 8                                    NaN  IPB (Bogor Agricultural University)
# 13                                   NaN  IPB (Bogor Agricultural University)
# 17                                   NaN  IPB (Bogor Agricultural University)
# 18                                   NaN  IPB (Bogor Agricultural University)
# 19   IPB (Bogor Agricultural University)                                  NaN
# ..                                   ...                                  ...
# 751                                  NaN  IPB (Bogor Agricultural University)
# 753                                  NaN  IPB (Bogor Agricultural University)
# 754                                  NaN  IPB (Bogor Agricultural University)
# 760                                  NaN  IPB (Bogor Agricultural University)
# 764                                  NaN  IPB (Bogor Agricultural University)
#
#     dc.title[IND] dc.title[]  \
# 8             NaN        NaN
# 13            NaN        NaN
# 17            NaN        NaN
# 18            NaN        NaN
# 19            NaN        NaN
# ..            ...        ...
# 751           NaN        NaN
# 753           NaN        NaN
# 754           NaN        NaN
# 760           NaN        NaN
# 764           NaN        NaN
#
#                                           dc.title[en]  \
# 8                                                  NaN
# 13                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19   Kajian penanda genetik gen cytochrome B dan da...
# ..                                                 ...
# 751                                                NaN
# 753                                                NaN
# 754                                                NaN
# 760                                                NaN
# 764                                                NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 8    Penggunaan Zeolit Beramonium dan Analog Hidrok...     NaN       NaN
# 13   Peranan Sisa-sisa Tanaman dalam Konservasi Tan...     NaN       NaN
# 17   Peranan Kerapatan Kayu dan Kerapatan Lembaran ...     NaN       NaN
# 18   Indeks Keberlanjutan Pengembangan Kawasan Sent...     NaN       NaN
# 19                                                 NaN     NaN       NaN
# ..                                                 ...     ...       ...
# 751  Beberapa Ciri Populasi Kambing di Desa Ciburuy...     NaN       NaN
# 753  Prediksi Ketersediaan Air Menggunakan Tank Mod...     NaN       NaN
# 754  Kajian Konsep Pengukuran BOD sebagai Indikator...     NaN       NaN
# 760  Hubungan Pemukiman Kumuh Dengan Pemenuhan Air ...     NaN       NaN
# 764  Beberapa Faktor Lingkungan yang Mempengaruhi P...     NaN       NaN
#
#     dc.type[id]
# 8           NaN
# 13          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# ..          ...
# 751         NaN
# 753         NaN
# 754         NaN
# 760         NaN
# 764         NaN
#
# [317 rows x 44 columns]
# Filtered rows from file: DT - Animal Science.csv
#                                        id    collection dc.contributor.author  \
# 51   19fb2b11-98df-4969-ae7a-40b456af371e  123456789/84                   NaN
# 77   2bc07825-2cd6-4e94-9d90-1244fca3331e  123456789/84                   NaN
# 102  3e266963-9196-4e43-8304-67976659d058  123456789/84                   NaN
# 112  4502cc92-d47b-4ce5-9098-12eb5de15b55  123456789/84                   NaN
# 144  5e7b8202-fb09-482c-bd36-84af99d7ea65  123456789/84                   NaN
# 216  985c837a-fdbc-477a-bc18-4f9f290620ad  123456789/84                   NaN
# 229  a451234e-d73b-49aa-b6d8-f11eab6ff279  123456789/84                   NaN
# 245  aa1d2d49-7f1a-48d2-a2b2-58a3c007fa49  123456789/84                   NaN
# 248  ab58ab16-8d27-4626-898e-2d4f90a11dad  123456789/84                   NaN
#
#     dc.contributor.author[] dc.date.updated[]  \
# 51          Ichsan, Muhamad               NaN
# 77         Liwa, Abdul Muin               NaN
# 102          Inounu, Ismeth               NaN
# 112   Siregar, Abdul Rahman               NaN
# 144         Yurmiaty, Husmy               NaN
# 216       Lubis, Amir Hasan               NaN
# 229   Rotib, Laily Agustina               NaN
# 245    Sirait, Celly Helena               NaN
# 248    Saramony, Umbu Pombu               NaN
#
#                              dc.description.abstract[]  \
# 51   Penelitian ini dilandasi oleh latar belakang p...
# 77   PEnelitian ini bertujuan untuk mengetahui : (1...
# 102  Di Stasiun Pemuliaan Balai Penelitian Ternak d...
# 112  Ternak domba di Indonesia pada umumnya dipelih...
# 144  Penelitian ini dilakukan mulai bulan Oktober 1...
# 216  Penelitian dilakukan mulai bulan Maret 1990 sa...
# 229  Tujuan percobaan adalah untuk mengkaji hasil f...
# 245  Dali merupakan olahan susu tradisional dari da...
# 248  Penelitian dibagi dalam tiga tahap, masing-mas...
#
#     dc.description.abstract[en] dc.description.abstract[id]  \
# 51                          NaN                         NaN
# 77                          NaN                         NaN
# 102                         NaN                         NaN
# 112                         NaN                         NaN
# 144                         NaN                         NaN
# 216                         NaN                         NaN
# 229                         NaN                         NaN
# 245                         NaN                         NaN
# 248                         NaN                         NaN
#
#                          dc.description.provenance[en]  \
# 51   Submitted by Hana Webometrics (hana_webo@ipb.a...
# 77   Submitted by Hana Webometrics (hana_webo@ipb.a...
# 102  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 112  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 144  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 216  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 229  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 245  Submitted by Hana Webometrics (hana_webo@ipb.a...
# 248  Submitted by Hana Webometrics (hana_webo@ipb.a...
#
#     dc.description.sponsorship[id]  ... dc.subject[en] dc.title.alternative[]  \
# 51                             NaN  ...            NaN                    NaN
# 77                             NaN  ...            NaN                    NaN
# 102                            NaN  ...            NaN                    NaN
# 112                            NaN  ...            NaN                    NaN
# 144                            NaN  ...            NaN                    NaN
# 216                            NaN  ...            NaN                    NaN
# 229                            NaN  ...            NaN                    NaN
# 245                            NaN  ...            NaN                    NaN
# 248                            NaN  ...            NaN                    NaN
#
#     dc.title.alternative[en]             dc.title.alternative[id]  \
# 51                       NaN  IPB (Bogor Agricultural University)
# 77                       NaN  IPB (Bogor Agricultural University)
# 102                      NaN  IPB (Bogor Agricultural University)
# 112                      NaN  IPB (Bogor Agricultural University)
# 144                      NaN  IPB (Bogor Agricultural University)
# 216                      NaN  IPB (Bogor Agricultural University)
# 229                      NaN  IPB (Bogor Agricultural University)
# 245                      NaN  IPB (Bogor Agricultural University)
# 248                      NaN  IPB (Bogor Agricultural University)
#
#                                             dc.title[] dc.title[e]  \
# 51                                                 NaN         NaN
# 77                                                 NaN         NaN
# 102                                                NaN         NaN
# 112                                                NaN         NaN
# 144                                                NaN         NaN
# 216  The response of broiler on lowered protein in ...         NaN
# 229                                                NaN         NaN
# 245                                                NaN         NaN
# 248                                                NaN         NaN
#
#     dc.title[en]                                       dc.title[id]  \
# 51           NaN     Respon broiler terhadap suplementasi vitamin C
# 77           NaN        Produktivitas sapi bali di Sulawesi Selatan
# 102          NaN            Keragaan produksi ternak domba prolifik
# 112          NaN  Perbaikan sistem produksi untuk peningkatan pr...
# 144          NaN  Pengaruh pakan, umur potong dan jenis kelamin ...
# 216          NaN  Respons ayam broiler terhadap penurunan tingka...
# 229          NaN  Penggunaan bungkil kedelai yang difermentasi d...
# 245          NaN  Penggunaan susu sapi fries holland untuk pembu...
# 248          NaN  Keadaan iklim mikro dan respons biologik terna...
#
#     dc.type[en] dc.type[id]
# 51          NaN         NaN
# 77          NaN         NaN
# 102         NaN         NaN
# 112         NaN         NaN
# 144         NaN         NaN
# 216         NaN         NaN
# 229         NaN         NaN
# 245         NaN         NaN
# 248         NaN         NaN
#
# [9 rows x 32 columns]
# Filtered rows from file: DT - Mathematics and Natural Science.csv
#                                        id    collection dc.contributor.author  \
# 10   0863e10c-8ed3-4476-bbc2-131ab0c1b632  123456789/90                   NaN
# 286  aa9b6211-4150-42d3-9284-6efe883a1521  123456789/90                   NaN
# 309  b8cc99dc-f7ae-4c02-a067-302e1464dbe1  123456789/90                   NaN
#
#         dc.contributor.author[] dc.date.updated[] dc.description.abstract  \
# 10            Masoem, Toemin A.               NaN                     NaN
# 286                  Las, Irsal               NaN                     NaN
# 309  Lolombulan, Julius Hendrik               NaN                     NaN
#
#                              dc.description.abstract[]  \
# 10   Salah satu syarat untuk memperoleh STTB, siswa...
# 286  Telah dilakukan penelitian untuk merumuskan ne...
# 309                                                NaN
#
#     dc.description.abstract[en] dc.description.abstract[id]  \
# 10                          NaN                         NaN
# 286                         NaN                         NaN
# 309                         NaN                         NaN
#
#     dc.description.abstract[ind]  ... dc.title.alternative  \
# 10                           NaN  ...                  NaN
# 286                          NaN  ...                  NaN
# 309                          NaN  ...                  NaN
#
#     dc.title.alternative[] dc.title.alternative[en]  \
# 10                     NaN                      NaN
# 286                    NaN                      NaN
# 309                    NaN                      NaN
#
#                 dc.title.alternative[id] dc.title[] dc.title[en]  \
# 10   IPB (Bogor Agricultural University)        NaN          NaN
# 286  IPB (Bogor Agricultural University)        NaN          NaN
# 309  IPB (Bogor Agricultural University)        NaN          NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 10             Sebaran Empirik Nilai EBTANAS Dan UMPTN     NaN       NaN
# 286  Pewilayahan Komoditi Pertanian Berdasarkan Mod...     NaN       NaN
# 309  NEM SMA sebagai Indikator Keberhasilan Belajar...     NaN       NaN
#
#     dc.type[id]
# 10          NaN
# 286         NaN
# 309         NaN
#
# [3 rows x 42 columns]
# Filtered rows from file: DT - Agriculture.csv
#                                        id     collection  \
# 123  2461ff59-bbc9-4974-b98a-fc1b02f0e45a  123456789/160
# 183  3490b279-9252-4a9f-a13b-b0b7cd24036c  123456789/160
# 353  6cef4c79-5a09-463b-a613-1e38eddd5a05  123456789/160
# 381  77bae311-263f-440a-b4ee-f20ebe3bf06d  123456789/160
# 429  899698e7-97a2-4754-9e3d-200c8805bfa4  123456789/160
# 463  96390540-cf14-4db8-a3f2-ac4e2ec4e948  123456789/160
# 502  a48ad949-69e1-462b-a0b9-2337089d28c3  123456789/160
# 516  a856ce11-e509-4a37-8e1d-9b30e917be75  123456789/160
# 746  f1a1223a-b495-496d-a9cb-df5bffaaf83d  123456789/160
#
#     dc.contributor.author       dc.contributor.author[] dc.date.updated[]  \
# 123                   NaN      Mubiyanto, Bambang Odang               NaN
# 183                   NaN                 Marwoto, Budi               NaN
# 353                   NaN                       Aprisal               NaN
# 381                   NaN                 Nandika, Dodi               NaN
# 429                   NaN       Simanungkalit, Djaendar               NaN
# 463                   NaN              Hamid, Hasmiandy               NaN
# 502                   NaN             Aini, M. Hanafiah               NaN
# 516                   NaN     Sudiatso, Ignatius Sugeng               NaN
# 746                   NaN  Sitanggang, Jamuda Marulitua               NaN
#
#     dc.description.abstract  \
# 123                     NaN
# 183                     NaN
# 353                     NaN
# 381                     NaN
# 429                     NaN
# 463                     NaN
# 502                     NaN
# 516                     NaN
# 746                     NaN
#
#                              dc.description.abstract[]  \
# 123  Stevia rebaudiana Bertoni adalah tanaman sumbe...
# 183  Penelitian dilakukan dengan tujuan menghimpun ...
# 353  Lahan alang-alang merupakan lahan kering yang ...
# 381  Kumbang ambrosia Platypcs trepanatus (Chapman ...
# 429  Budidaya basah merupakan teknik agronomik yang...
# 463                                                NaN
# 502  Tulisan ini merupakan hasil penelitian tentang...
# 516  Tujuan penelitian untuk mengetahui pengaruh et...
# 746  Pada lahan kering, pertumbuhan tanaman sangat ...
#
#                            dc.description.abstract[en]  \
# 123                                                NaN
# 183                                                NaN
# 353  Imperata grass occupy a large area of uplands ...
# 381                                                NaN
# 429                                                NaN
# 463  The abundance and species richness of herbivor...
# 502                                                NaN
# 516                                                NaN
# 746                                                NaN
#
#     dc.description.abstract[id] dc.description.abstract[id_IDen]  ...  \
# 123                         NaN                              NaN  ...
# 183                         NaN                              NaN  ...
# 353                         NaN                              NaN  ...
# 381                         NaN                              NaN  ...
# 429                         NaN                              NaN  ...
# 463                         NaN                              NaN  ...
# 502                         NaN                              NaN  ...
# 516                         NaN                              NaN  ...
# 746                         NaN                              NaN  ...
#
#     dc.title.alternative[] dc.title.alternative[en]  \
# 123                    NaN                      NaN
# 183                    NaN                      NaN
# 353                    NaN                      NaN
# 381                    NaN                      NaN
# 429                    NaN                      NaN
# 463                    NaN                      NaN
# 502                    NaN                      NaN
# 516                    NaN                      NaN
# 746                    NaN                      NaN
#
#                 dc.title.alternative[id] dc.title[I] dc.title[]  \
# 123  IPB (Bogor Agricultural University)         NaN        NaN
# 183  IPB (Bogor Agricultural University)         NaN        NaN
# 353  IPB (Bogor Agricultural University)         NaN        NaN
# 381  IPB (Bogor Agricultural University)         NaN        NaN
# 429  IPB (Bogor Agricultural University)         NaN        NaN
# 463  IPB (Bogor Agricultural University)         NaN        NaN
# 502  IPB (Bogor Agricultural University)         NaN        NaN
# 516  IPB (Bogor Agricultural University)         NaN        NaN
# 746  IPB (Bogor Agricultural University)         NaN        NaN
#
#                                           dc.title[en]  \
# 123                                                NaN
# 183                                                NaN
# 353  The study of the reclamation of imperata margi...
# 381                                                NaN
# 429                                                NaN
# 463  Comunity of pod borer insects and its parasito...
# 502                                                NaN
# 516                                                NaN
# 746                                                NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 123  Analisis pertumbuhan tanaman stevia rebaudiana...     NaN       NaN
# 183  Nematoda bentuk ginjal (Rotylenchulus reniform...     NaN       NaN
# 353  Kajian reklamasi lahan marginal alang-alang da...     NaN       NaN
# 381  Bionomi Kumbang Ambrosia Platypus trepanatus (...     NaN       NaN
# 429  Penerapan budidaya basah tanaman kedelai (Glyc...     NaN       NaN
# 463  Komunitas serangga herbivora penggerek polong ...     NaN       NaN
# 502  Penyakit bakteri pada kedelai di Kalimantan Se...     NaN       NaN
# 516  Pengaruh etilen pada berbagai taraf pemupukan ...     NaN       NaN
# 746  Respon beberapa varietas terhadap tingkat pemb...     NaN       NaN
#
#     dc.type[id]
# 123         NaN
# 183         NaN
# 353         NaN
# 381         NaN
# 429         NaN
# 463         NaN
# 502         NaN
# 516         NaN
# 746         NaN
#
# [9 rows x 47 columns]
# Filtered rows from file: MT - Professional Master.csv
#                                        id    collection dc.contributor.author  \
# 194  357c43b7-0377-4116-accd-4e479f3a2b37  123456789/81                   NaN
# 348  652edd66-2310-4bc2-a734-c31a3da7afa3  123456789/81                   NaN
# 411  74731bd1-8c29-48a8-b60b-c70b13c2158e  123456789/81                   NaN
#
#       dc.contributor.author[] dc.date.updated[]  \
# 194  Hanafi, Dian Noor Tamzis               NaN
# 348           Sukaca, Bambang               NaN
# 411            Noeraeni, Dede               NaN
#
#                                dc.description.abstract  \
# 194  Pasca krisis ekonomi tahun 1998 dan dihadapkan...
# 348                                                NaN
# 411  Usaha pengolahan hasil perikanan di Indonesia ...
#
#     dc.description.abstract[IND] dc.description.abstract[Id_ID]  \
# 194                          NaN                            NaN
# 348                          NaN                            NaN
# 411                          NaN                            NaN
#
#     dc.description.abstract[Ind] dc.description.abstract[]  ...  \
# 194                          NaN                       NaN  ...
# 348                          NaN                       NaN  ...
# 411                          NaN                       NaN  ...
#
#     dc.title[Id_ID] dc.title[] dc.title[en-US] dc.title[en]  \
# 194             NaN        NaN             NaN          NaN
# 348             NaN        NaN             NaN          NaN
# 411             NaN        NaN             NaN          NaN
#
#                                           dc.title[id] dc.title[in] dc.type  \
# 194  Pengembangan Program Kecakapan Hidup (Life Ski...          NaN     NaN
# 348  Kajian Prospek Usaha Tanaman Hias Akuarium Pad...          NaN     NaN
# 411  Analisis Usaha Dan Prospek Pengembangan Pada U...          NaN     NaN
#
#     dc.type[] dc.type[en] dc.type[id]
# 194       NaN         NaN         NaN
# 348       NaN         NaN         NaN
# 411       NaN         NaN         NaN
#
# [3 rows x 53 columns]
# Filtered rows from file: MT - Forestrycsv.csv
#                                        id    collection dc.contributor.author  \
# 492  d16f7993-9a41-4c3c-8e3e-c2b3d4cd6bb0  123456789/75                   NaN
# 494  3517a640-9c9d-43a8-8747-92c86065d9c9  123456789/75                   NaN
#
#     dc.contributor.author[] dc.date.updated[]  \
# 492          Mulyana, Dadan               NaN
# 494                    Danu               NaN
#
#                                dc.description.abstract  \
# 492  Kegiatan rehabilitasi sangat perlu untuk dieva...
# 494                                                NaN
#
#     dc.description.abstract[IND] dc.description.abstract[]  \
# 492                          NaN                       NaN
# 494                          NaN                       NaN
#
#     dc.description.abstract[en] dc.description.abstract[id]  ...  \
# 492                         NaN                         NaN  ...
# 494                         NaN                         NaN  ...
#
#     dc.title.alternative[en]             dc.title.alternative[id]  \
# 492                      NaN  IPB (Bogor Agricultural University)
# 494                      NaN  IPB (Bogor Agricultural University)
#
#     dc.title[IND] dc.title[] dc.title[en]  \
# 492           NaN        NaN          NaN
# 494           NaN        NaN          NaN
#
#                                           dc.title[id] dc.type dc.type[]  \
# 492  Kualitas Tanah Pada Berbagai Penutupan Lahan H...     NaN       NaN
# 494  Hubungan Antara Umur Dan Tingkat Juvenilitas D...     NaN       NaN
#
#      dc.type[en] dc.type[id]
# 492          NaN         NaN
# 494          NaN         NaN
#
# [2 rows x 49 columns]
# Filtered rows from file: MT - Veterinary Science.csv
#                                        id    collection  \
# 216  3b57d9d0-ecf6-4706-af0b-ff327a7d3873  123456789/72
# 863  f4f566c9-eada-4c9f-b50f-210289fe1b4f  123456789/72
#
#              dc.contributor.author         dc.contributor.author[]  \
# 216  Caropeboka, Alberdina Mahdani                             NaN
# 863                            NaN  Harianja, Duma Sari Margaretha
#
#     dc.date.updated[]                            dc.description.abstract  \
# 216               NaN                                                NaN
# 863               NaN  UHT (Ultra High Temperature) is a thermal proc...
#
#     dc.description.abstract[IND] dc.description.abstract[]  \
# 216                          NaN                       NaN
# 863                          NaN                       NaN
#
#     dc.description.abstract[en]  \
# 216                         NaN
# 863                         NaN
#
#                            dc.description.abstract[id]  ...  \
# 216  Pimpinella  alpina Koord. dengan nama daerahny...  ...
# 863                                                NaN  ...
#
#                 dc.title.alternative[id] dc.title[IND] dc.title[]  \
# 216  IPB (Bogor Agricultural University)           NaN        NaN
# 863  IPB (Bogor Agricultural University)           NaN        NaN
#
#     dc.title[en]                                       dc.title[id] dc.type  \
# 216          NaN  Pengaruh ekstrak akar pimpinella alpina koord....     NaN
# 863          NaN  Kajian Tingkat Keamanan Susu Uht  (Ultra High ...     NaN
#
#     dc.type[] dc.type[en] dc.type[id] dcterms.title[]
# 216       NaN         NaN      Thesis             NaN
# 863       NaN         NaN         NaN             NaN
#
# [2 rows x 48 columns]
# Filtered rows from file: MT - Human Ecology.csv
#                                        id    collection dc.contributor.author  \
# 174  8b012d13-7d7c-4452-8f2d-8c8f295cb797  123456789/79                   NaN
# 947  a38a86db-dc0d-4ba7-aba0-f5980582d5e4  123456789/79                   NaN
#
#     dc.contributor.author[] dc.date.updated[]  \
# 174                Agustini               NaN
# 947        Yani, Diarsi Eka               NaN
#
# ...
# 403                           NaN                            NaN
# 404                           NaN                            NaN
# 405                           NaN                            NaN
# 409                           NaN                            NaN
# 412                           NaN                            NaN
# 413                           NaN                            NaN
# 417                           NaN                            NaN
# 421                           NaN                            NaN
# 422                           NaN                            NaN
# 423                           NaN                            NaN
# 424                           NaN                            NaN
# 427                           NaN                            NaN
# 431                           NaN                            NaN
# 433                           NaN                            NaN
# 434                           NaN                            NaN
# 435                           NaN                            NaN
# 436                           NaN                            NaN
# 437                           NaN                            NaN
# 444                           NaN                            NaN
# 453                           NaN                            NaN
# 860                           NaN                            NaN
# 1695                          NaN                            NaN
# 6603                          NaN                            NaN
# 9515                          NaN                            NaN
# 9519                          NaN                            NaN
# 9533                          NaN                            NaN
# 12034                         NaN                            NaN
# 12036                         NaN                            NaN
# 12037                         NaN                            NaN
# 12055                         NaN                            NaN
# 12504                         NaN                            NaN
# 12505                         NaN                            NaN
# 12506                         NaN                            NaN
# 12507                         NaN                            NaN
#
#       dc.description.abstract[id]  ... dc.title.alternative[en]  \
# 218                           NaN  ...                      NaN
# 219                           NaN  ...                      NaN
# 220                           NaN  ...                      NaN
# 221                           NaN  ...                      NaN
# 222                           NaN  ...                      NaN
# 366                           NaN  ...                      NaN
# 367                           NaN  ...                      NaN
# 388                           NaN  ...                      NaN
# 390                           NaN  ...                      NaN
# 394                           NaN  ...                      NaN
# 395                           NaN  ...                      NaN
# 399                           NaN  ...                      NaN
# 402                           NaN  ...                      NaN
# 403                           NaN  ...                      NaN
# 404                           NaN  ...                      NaN
# 405                           NaN  ...                      NaN
# 409                           NaN  ...                      NaN
# 412                           NaN  ...                      NaN
# 413                           NaN  ...                      NaN
# 417                           NaN  ...                      NaN
# 421                           NaN  ...                      NaN
# 422                           NaN  ...                      NaN
# 423                           NaN  ...                      NaN
# 424                           NaN  ...                      NaN
# 427                           NaN  ...                      NaN
# 431                           NaN  ...                      NaN
# 433                           NaN  ...                      NaN
# 434                           NaN  ...                      NaN
# 435                           NaN  ...                      NaN
# 436                           NaN  ...                      NaN
# 437                           NaN  ...                      NaN
# 444                           NaN  ...                      NaN
# 453                           NaN  ...                      NaN
# 860                           NaN  ...                      NaN
# 1695                          NaN  ...                      NaN
# 6603                          NaN  ...                      NaN
# 9515                          NaN  ...                      NaN
# 9519                          NaN  ...                      NaN
# 9533                          NaN  ...                      NaN
# 12034                         NaN  ...                      NaN
# 12036                         NaN  ...                      NaN
# 12037                         NaN  ...                      NaN
# 12055                         NaN  ...                      NaN
# 12504                         NaN  ...                      NaN
# 12505                         NaN  ...                      NaN
# 12506                         NaN  ...                      NaN
# 12507                         NaN  ...                      NaN
#
#                   dc.title.alternative[id] dc.title[IND] dc.title[]  \
# 218    IPB (Bogor Agricultural University)           NaN        NaN
# 219    IPB (Bogor Agricultural University)           NaN        NaN
# 220    IPB (Bogor Agricultural University)           NaN        NaN
# 221    IPB (Bogor Agricultural University)           NaN        NaN
# 222    IPB (Bogor Agricultural University)           NaN        NaN
# 366    IPB (Bogor Agricultural University)           NaN        NaN
# 367    IPB (Bogor Agricultural University)           NaN        NaN
# 388    IPB (Bogor Agricultural University)           NaN        NaN
# 390    IPB (Bogor Agricultural University)           NaN        NaN
# 394    IPB (Bogor Agricultural University)           NaN        NaN
# 395    IPB (Bogor Agricultural University)           NaN        NaN
# 399    IPB (Bogor Agricultural University)           NaN        NaN
# 402    IPB (Bogor Agricultural University)           NaN        NaN
# 403    IPB (Bogor Agricultural University)           NaN        NaN
# 404    IPB (Bogor Agricultural University)           NaN        NaN
# 405    IPB (Bogor Agricultural University)           NaN        NaN
# 409    IPB (Bogor Agricultural University)           NaN        NaN
# 412    IPB (Bogor Agricultural University)           NaN        NaN
# 413    IPB (Bogor Agricultural University)           NaN        NaN
# 417    IPB (Bogor Agricultural University)           NaN        NaN
# 421    IPB (Bogor Agricultural University)           NaN        NaN
# 422    IPB (Bogor Agricultural University)           NaN        NaN
# 423    IPB (Bogor Agricultural University)           NaN        NaN
# 424    IPB (Bogor Agricultural University)           NaN        NaN
# 427    IPB (Bogor Agricultural University)           NaN        NaN
# 431    IPB (Bogor Agricultural University)           NaN        NaN
# 433    IPB (Bogor Agricultural University)           NaN        NaN
# 434    IPB (Bogor Agricultural University)           NaN        NaN
# 435    IPB (Bogor Agricultural University)           NaN        NaN
# 436    IPB (Bogor Agricultural University)           NaN        NaN
# 437    IPB (Bogor Agricultural University)           NaN        NaN
# 444    IPB (Bogor Agricultural University)           NaN        NaN
# 453    IPB (Bogor Agricultural University)           NaN        NaN
# 860    IPB (Bogor Agricultural University)           NaN        NaN
# 1695   IPB (Bogor Agricultural University)           NaN        NaN
# 6603   IPB (Bogor Agricultural University)           NaN        NaN
# 9515   IPB (Bogor Agricultural University)           NaN        NaN
# 9519   IPB (Bogor Agricultural University)           NaN        NaN
# 9533   IPB (Bogor Agricultural University)           NaN        NaN
# 12034  IPB (Bogor Agricultural University)           NaN        NaN
# 12036  IPB (Bogor Agricultural University)           NaN        NaN
# 12037  IPB (Bogor Agricultural University)           NaN        NaN
# 12055  IPB (Bogor Agricultural University)           NaN        NaN
# 12504  IPB (Bogor Agricultural University)           NaN        NaN
# 12505  IPB (Bogor Agricultural University)           NaN        NaN
# 12506  IPB (Bogor Agricultural University)           NaN        NaN
# 12507  IPB (Bogor Agricultural University)           NaN        NaN
#
#       dc.title[en]                                       dc.title[id] dc.type  \
# 218            NaN  Pengaruh Beberapa Jenis Aktivator terhadap Kec...     NaN
# 219            NaN  Perencangan Taman Cluster Jingganagara Banyaks...     NaN
# 220            NaN         Studi Produksi Papain Enam Genotipe Pepaya     NaN
# 221            NaN  Pengelolaan Lanskap Lapangan Golf Di Padang Go...     NaN
# 222            NaN  Viabilitas Benih Pepaya (Carica papaya L.) Beb...     NaN
# 366            NaN  Evaluasi Beberapa Genotipe Kedelai (Glycine ma...     NaN
# 367            NaN  Pengaruh 2ip dan Air Kelapa Terhadap Multiplik...     NaN
# 388            NaN  Pengaruh Teknis Pemasangan Lanjaran Terhadap P...     NaN
# 390            NaN  Perencanaan Lanskap Kawasan Ekowisata Lahan Ba...     NaN
# 394            NaN  Evaluasi Tata Hijau Jalan pada Tiga Kawasan Pe...     NaN
# 395            NaN  Studi Pemanfaatan Kulit Melinjo (Gnetum gnemon...     NaN
# 399            NaN  Regenerasi Tanaman Tomat (Lycopersion esculent...     NaN
# 402            NaN  Studi Induksi Kalus Androgenik Pisang Batu [Mu...     NaN
# 403            NaN  Keragaan Karakter Agronomi Generasi F3 Enam Pe...     NaN
# 404            NaN  Uji Potensi Minyak Sereh Wangi Dalam Pengendal...     NaN
# 405            NaN  Kualitas Buah Pisang Ambon Putih (Musa sapient...     NaN
# 409            NaN  Pelaksanaan Pekerjaan Taman Rumah dan Pemeliha...     NaN
# 412            NaN  Perancangan Lanskap Zona Depan Kampus Universi...     NaN
# 413            NaN  Pengaruh Jenis Sitokinin Dan Air Kelapa Terhad...     NaN
# 417            NaN  Efektivitas Herbisida Glifosat untuk Mengendal...     NaN
# 421            NaN  Pengaruh Jenis Media Preservasi dan Lama PEnyi...     NaN
# 422            NaN  Pengelolaan Pemangkasan Tanaman Teh (Camellia ...     NaN
# 423            NaN  Studi Pertumbuhan dan Produktivitas Ratoon Pad...     NaN
# 424            NaN  Perencaaan Lanskap Wisata Budaya Perkampingan ...     NaN
# 427            NaN  Evaluasi Karakter Visual Arsitektur Botanis Pohon     NaN
# 431            NaN  Perencanaan Kawasan Wisata Agro Jeruk Di Cianj...     NaN
# 433            NaN  Pengaruh Dosis Kapur dan Pupuk Daun Organik Di...     NaN
# 434            NaN  Pengaruh Gibberellin (GA3) dan Ukuran Umbi ter...     NaN
# 435            NaN  Perencanaan Kawasan Wisata Agro Buah Tropis Be...     NaN
# 436            NaN  Pengaruh Status Mutu Benih dan LIngkungan Prod...     NaN
# 437            NaN  Pengaruh Inokulasi Cendawan Mikoriza Arbuskula...     NaN
# 444            NaN  Tata laksana kerja PT Airmas Asri sebagai peru...     NaN
# 453            NaN  PEnggunaan Insektisida Sintetik dan Botani pad...     NaN
# 860            NaN  Pengaruh Volume dan Frekuensi Penyiraman terha...     NaN
# 1695           NaN  Studi Behavior Setting dan Behavioral Mapping ...     NaN
# 6603           NaN  PEngaruh Lama Waktu Strangulasi Cabang Terhada...     NaN
# 9515           NaN  Ketahanan Varietas Pisang (Musa spp.) terhadap...     NaN
# 9519           NaN  Perincian Gen Protein Selubung Zucchini Yellow...     NaN
# 9533           NaN  Pengujian Aktivitas Biologi Campuran Ekstrak T...     NaN
# 12034          NaN  Karakteristik Kadar Air Tanah dan Hisapan Matr...     NaN
# 12036          NaN  Analisis Perubahan Penggunaan Lahan dan Dinami...     NaN
# 12037          NaN  Dampak Perubahan Penggunaan Lahan Gambut Terha...     NaN
# 12055          NaN  Produktivitas Lahan Pertanian Perkotaan Dengan...     NaN
# 12504          NaN  Pemanfaatan Sistem Informasi Geografi dan Peng...     NaN
# 12505          NaN  Pengaruh Nitrogen terhadap Produksi Herba dan ...     NaN
# 12506          NaN  C-Organik yang Dapat Dioksidasi pada Kompos ya...     NaN
# 12507          NaN  Perubahan Karakter Tanah pada Kawasan Reklamas...     NaN
#
#       dc.type[] dc.type[en] dc.type[id]
# 218         NaN         NaN         NaN
# 219         NaN         NaN         NaN
# 220         NaN         NaN         NaN
# 221         NaN         NaN         NaN
# 222         NaN         NaN         NaN
# 366         NaN         NaN         NaN
# 367         NaN         NaN         NaN
# 388         NaN         NaN         NaN
# 390         NaN         NaN         NaN
# 394         NaN         NaN         NaN
# 395         NaN         NaN         NaN
# 399         NaN         NaN         NaN
# 402         NaN         NaN         NaN
# 403         NaN         NaN         NaN
# 404         NaN         NaN         NaN
# 405         NaN         NaN         NaN
# 409         NaN         NaN         NaN
# 412         NaN         NaN         NaN
# 413         NaN         NaN         NaN
# 417         NaN         NaN         NaN
# 421         NaN         NaN         NaN
# 422         NaN         NaN         NaN
# 423         NaN         NaN         NaN
# 424         NaN         NaN         NaN
# 427         NaN         NaN         NaN
# 431         NaN         NaN         NaN
# 433         NaN         NaN         NaN
# 434         NaN         NaN         NaN
# 435         NaN         NaN         NaN
# 436         NaN         NaN         NaN
# 437         NaN         NaN         NaN
# 444         NaN         NaN         NaN
# 453         NaN         NaN         NaN
# 860         NaN         NaN         NaN
# 1695        NaN         NaN         NaN
# 6603        NaN         NaN         NaN
# 9515        NaN         NaN         NaN
# 9519        NaN         NaN         NaN
# 9533        NaN         NaN         NaN
# 12034       NaN         NaN         NaN
# 12036       NaN         NaN         NaN
# 12037       NaN         NaN         NaN
# 12055       NaN         NaN         NaN
# 12504       NaN         NaN         NaN
# 12505       NaN         NaN         NaN
# 12506       NaN         NaN         NaN
# 12507       NaN         NaN         NaN
#
# [47 rows x 49 columns]
# Filtered rows from file: UT - Faculty of Animal Science.csv
#                                         id     collection  \
# 1647  588b3b93-7d79-45bf-bc6a-9afa9cba72ed  123456789/109
#
#      dc.contributor.author dc.contributor.author[] dc.date.updated[]  \
# 1647                   NaN     Septiarini, Ayu Ike               NaN
#
#      dc.description.abstract dc.description.abstract[IND]  \
# 1647                     NaN                          NaN
#
#      dc.description.abstract[] dc.description.abstract[en]  \
# 1647                       NaN                         NaN
#
#      dc.description.abstract[id]  ... dc.title[] dc.title[en]  \
# 1647                         NaN  ...        NaN          NaN
#
#                                            dc.title[id] dc.type dc.type[IND]  \
# 1647  Karkas dan Potongan Komersial Ayam Hasil Persi...     NaN          NaN
#
#      dc.type[] dc.type[en] dc.type[id] dcterms.abstract[] dcterms.type[]
# 1647       NaN         NaN         NaN                NaN            NaN
#
# [1 rows x 52 columns]
# Total number of rows with 'IPB (Bogor Agricultural University)' in the 'title' column: 930

# %%
import os
import pandas as pd
import re

# Define the folders
folders = ['Dissertations', 'Master', 'Undergraduate']

# Initialize an empty DataFrame to hold the combined data
combined_df = pd.DataFrame()

# Define the regex patterns for column prefixes
patterns = {
    'title': r'^dc\.title',
    'abstract': r'^dc\.description\.abstract',
    'keyword': r'^dc\.subject\.keyword',
    'author': r'^dc\.contributor\.author',
    'type': r'^dc\.type',
    'url': r'^dc\.identifier\.uri',
}

# Function to extract columns based on regex pattern and select the first non-null value
def extract_columns(df, pattern):
    matching_columns = [col for col in df.columns if re.match(pattern, col)]
    if matching_columns:
        # Select the first non-null value across the matching columns
        return df[matching_columns].bfill(axis=1).iloc[:, 0]
    else:
        return pd.Series([None] * len(df))

# Function to truncate text to a specified number of words
def truncate_text(text, max_words=1000):
    if pd.isna(text):
        return text
    words = text.split()
    if len(words) > max_words:
        return ' '.join(words[:max_words]) + '...'
    return text

# Function to check the maximum word length in a column
def check_max_word_length(df, column_name):
    max_length = df[column_name].apply(lambda x: len(str(x).split()) if pd.notna(x) else 0).max()
    return max_length

# Loop through each folder
for folder in folders:
    # Loop through each CSV file in the folder
    for filename in os.listdir(f"/content/drive/MyDrive/Colab Notebooks/dataset_magang/{folder}/csv/"):
        if filename.endswith('.csv'):
            # Construct the file path
            file_path = os.path.join(f"/content/drive/MyDrive/Colab Notebooks/dataset_magang/{folder}/csv/", filename)

            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path)

            # Extract department name from the filename (assuming the filename contains the department)
            department_name = os.path.splitext(filename)[0]  # This will give you the filename without the extension

            # Create a simplified DataFrame using regex for column matching
            simplified_df = pd.DataFrame()

            # Apply regex-based column extraction for each key in patterns
            for key, pattern in patterns.items():
                simplified_df[key] = extract_columns(df, pattern)

            # Add a 'department' column to the DataFrame
            simplified_df['department'] = department_name

            # Fill 'type' column with folder name if it is NaN
            simplified_df['type'] = simplified_df['type'].fillna(folder)

            # Append the simplified DataFrame to the combined DataFrame
            combined_df = pd.concat([combined_df, simplified_df], ignore_index=True)

# Drop rows with all NaN values in the combined DataFrame
combined_df_clean = combined_df.dropna(how='all')

# Drop rows where the 'abstract' column is null
combined_df_clean = combined_df_clean.dropna(subset=['abstract'])

# Replace '||' with ', ' in specified columns
columns_to_replace = ['abstract', 'author', 'keyword', 'title', 'type']
for column in columns_to_replace:
    combined_df_clean[column] = combined_df_clean[column].str.replace('||', ', ', regex=False)

# Check max word length in 'abstract' column before truncation
max_length_before = check_max_word_length(combined_df_clean, 'abstract')
print(f"Maximum word length in 'abstract' before truncation: {max_length_before}")

# Truncate abstracts to 1000 words
combined_df_clean['abstract'] = combined_df_clean['abstract'].apply(truncate_text)

# Check max word length in 'abstract' column after truncation
max_length_after = check_max_word_length(combined_df_clean, 'abstract')
print(f"Maximum word length in 'abstract' after truncation: {max_length_after}")

# Save the combined and simplified DataFrame to a new CSV file
combined_df_clean.to_csv('df.csv', index=False)

print("Combined and simplified CSV created successfully with truncated abstracts.")
# Out:
# Maximum word length in 'abstract' before truncation: 4029
# Maximum word length in 'abstract' after truncation: 1000
# Combined and simplified CSV created successfully with truncated abstracts.

# %%
combined_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115145 entries, 0 to 122976
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   title       115145 non-null  object
#  1   abstract    115145 non-null  object
#  2   keyword     65311 non-null   object
#  3   author      115071 non-null  object
#  4   type        115145 non-null  object
#  5   url         115144 non-null  object
#  6   department  115145 non-null  object
# dtypes: object(7)
# memory usage: 7.0+ MB

# %%
combined_df_clean.head()
# Out:
#                                                title  \
# 0  Comparing Visual Attention, AI-Reface, and Hum...
# 1  Rancang Bangun Model Pelayanan Perizinan Inves...
# 2  Talent Management Strategy Development for Fut...
# 3  Development of Artificial Neural Network Model...
# 4  Kinerja Daya Saing, Efisiensi, Profitabilitas,...
#
#                                             abstract  \
# 0  Understanding the differential impact of human...
# 1  Investasi swasta merupakan bagian sumber pembi...
# 2  Kinerja berkelanjutan merupakan suatu kondisi ...
# 3  Berdasarkan Undang-Undang Nomor 10 tahun 1998 ...
# 4  RIRIS SHANTI. Kinerja Daya Saing, Efisiensi, P...
#
#                                              keyword                   author  \
# 0  Intelligence, Brand, Endorser, Neuromarketing,...        Akbari, Deni Adha
# 1  analytical hierarchy process (AHP), soft syste...              Subowo, Eko
# 2  Kinerja pegawai, Manajemen Talenta, employee p...            Hartono, Imam
# 3  faktor internal, Jaringan Saraf Tiruan, intern...  Solihati, Garin Pratiwi
# 4  Bank Digital, daya saing, Efisiensi, profitabi...            Shanti, Riris
#
#            type                                                url  \
# 0     Disertasi  http://repository.ipb.ac.id/handle/123456789/1...
# 1  Dissertation  http://repository.ipb.ac.id/handle/123456789/1...
# 2     Disertasi  http://repository.ipb.ac.id/handle/123456789/1...
# 3     Disertasi  http://repository.ipb.ac.id/handle/123456789/1...
# 4     Disertasi  http://repository.ipb.ac.id/handle/123456789/1...
#
#                department
# 0  DT - Magister Business
# 1  DT - Magister Business
# 2  DT - Magister Business
# 3  DT - Magister Business
# 4  DT - Magister Business

# %%
df = pd.read_csv('/content/df.csv')

df['combined_text'] = df['title'] + ' ' + df['abstract']



print(len(df['combined_text'][74].split()))
# Out:
# 382

# %%
# !pip install -U sympy
# Out:
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Collecting sympy
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 37.8 MB/s eta 0:00:00
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.5.1+cu121 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.13.3 which is incompatible.
# Successfully installed sympy-1.13.3

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np

# Load pre-trained model for embeddings
model_name = "sentence-transformers/all-MiniLM-L6-v2"  # Example model
model = SentenceTransformer(model_name)

# Load your dataframe
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df.csv')

# Create 'combined_text' column here, before accessing it
df['combined_text'] = df['title'] + ' ' + df['abstract']

# Assuming the text you want to embed is in the 'combined_text' column
# You previously created 'combined_text' from 'title' and 'abstract'
texts = df['combined_text'].tolist()  # Changed 'text' to 'combined_text'

# Generate embeddings for each text entry
embeddings = model.encode(texts, show_progress_bar=True)

# Add embeddings to your dataframe (as strings, for later storage)
df['embedding'] = [str(embedding) for embedding in embeddings]

# Save the dataframe with embeddings
df.to_csv('df_with_embeddings.csv', index=False)

print(f"Generated embeddings and saved to 'df_with_embeddings.csv'")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/3599 [00:00<?, ?it/s]
# Generated embeddings and saved to 'df_with_embeddings.csv'

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# Load the dataframe with embeddings
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df_with_embeddings.csv')

# Convert embeddings back from string to numpy arrays
df['embedding'] = df['embedding'].apply(lambda x: np.fromstring(x.strip('[]'), sep=','))

# Parameters
top_n_positives = 2  # Number of positive samples per anchor
top_n_negatives = 2  # Number of negative samples per anchor

# Prepare the embeddings and texts
all_embeddings = np.vstack(df['embedding'].values)  # Stack all embeddings vertically
# Instead of 'text', use 'combined_text' which contains the combined title and abstract
all_texts = df['combined_text'].tolist()  # Using the 'combined_text' column

# Prepare to store triplets
triplets = []

# Loop through each anchor and create triplets
for i in range(len(all_embeddings)):
    # Calculate cosine similarity between the i-th embedding and all other embeddings
    sim_scores = cosine_similarity([all_embeddings[i]], all_embeddings)[0]

    # Get indices of the top N most similar (positive) and least similar (negative) rows
    positive_indices = np.argsort(sim_scores)[::-1][1:top_n_positives + 1]  # Top similar, excluding self
    negative_indices = np.argsort(sim_scores)[:top_n_negatives]  # Least similar

    anchor = all_texts[i]
    positives = [all_texts[idx] for idx in positive_indices]
    negatives = [all_texts[idx] for idx in negative_indices]

    # Create triplets (anchor, positive, negative)
    for pos in positives:
        for neg in negatives:
            triplets.append((anchor, pos, neg))

# Save triplets to a new CSV file
triplets_df = pd.DataFrame(triplets, columns=['anchor', 'positive', 'negative'])
triplets_df.to_csv('triplets.csv', index=False)

print(f"Generated {len(triplets)} triplets and saved to 'triplets.csv'")
# Out:
# <ipython-input-5-0cc9611704aa>:9: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   df['embedding'] = df['embedding'].apply(lambda x: np.fromstring(x.strip('[]'), sep=','))
# Generated 460580 triplets and saved to 'triplets.csv'

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# torch 2.5.1+cu121 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.13.3 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from sentence_transformers import SentenceTransformer, SentenceTransformerTrainer, SentenceTransformerTrainingArguments
from sentence_transformers.losses import MultipleNegativesRankingLoss
from datasets import Dataset

# Load the pre-trained model
model_name = "sentence-transformers/paraphrase-MiniLM-L6-v2"  # Smaller model to reduce memory usage
model = SentenceTransformer(model_name)

import pandas as pd  # Import pandas

# Load the triplet dataset
triplets_df = pd.read_csv('triplets.csv')


# Convert triplet data to the format needed for training
train_data = []
for _, row in triplets_df.iterrows():
    anchor = row['anchor']
    positive = row['positive']
    negative = row['negative']
    train_data.append({'anchor': anchor, 'positive': positive, 'negative': negative})

# Convert to Dataset object
train_dataset = Dataset.from_pandas(pd.DataFrame(train_data))

# Loss function
loss = MultipleNegativesRankingLoss(model)

# Fine-tuning arguments with memory optimizations
training_args = SentenceTransformerTrainingArguments(
    output_dir="./finetuned_model",
    num_train_epochs=1,
    per_device_train_batch_size=4,  # Reduce this number
    save_steps=2000,
    logging_steps=500,
    gradient_accumulation_steps=4,  # Optional: accumulate gradients to compensate for smaller batch size
)


# Trainer
trainer = SentenceTransformerTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    loss=loss,
)

# Fine-tune the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained('./finetuned_model')

print("Fine-tuning complete and model saved.")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# /content/triplets.csv

# %%
from google.colab import files

files.download('triplets.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e7279641bdbc> in <cell line: 3>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('triplets.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: triplets.csv

# %%
# !ls -l triplets.csv
# Out:
# -rw-r--r-- 1 root root 3596931421 Dec 12 07:28 triplets.csv
